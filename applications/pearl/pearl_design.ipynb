# %%
from pearl_initial_formulation import *

# %%
from modeling.api import (edges_no_param, addobj, addineq, merge, 
setsolvefor, var_params, copy_dicts, OPT)
from graph.graphutils import flatten_tree, all_variables, all_edges
from presolver.tearing import dir_graph, min_arc_set_assign, min_arc_set
from graph.operators import reformulate, invert_edges
from modeling.transformations import transform_components
from graph.matrixview import render_incidence
from solver.runpipeline import model_to_problem
from solver.postprocess import print_outputs
import openmdao.api as om

# %%
edges, tree = model.generate_formulation()
edges_nopar =  edges_no_param(model, edges)
outset_initial = {comp: var[0] for comp,var in edges[1].items()}

# %%
model.components;

# %%
render_incidence(edges_nopar, tree, figname="pearl_default_hsm.png", save=False, rawvarname=True, 
                         dispendcomp=False, hideticks=True, patchwidth=4, figsize=((15,15)));
