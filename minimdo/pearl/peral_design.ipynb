# %%
from pearl_initial_formulation import *

# %%
from datastructures.api import (edges_no_param, addobj, addineq, merge, 
setsolvefor, var_params, copy_dicts, OPT)
from datastructures.graphutils import flatten_tree, all_variables, all_edges
from datastructures.tearing import dir_graph, min_arc_set_assign, min_arc_set
from datastructures.operators import reformulate, invert_edges
from datastructures.transformations import transform_components
from datastructures.rendering import render_incidence
from datastructures.runpipeline import model_to_problem
from datastructures.postprocess import print_outputs
import openmdao.api as om

# %%
edges, tree = model.generate_formulation()
edges_nopar =  edges_no_param(model, edges)
outset_initial = {comp: var[0] for comp,var in edges[1].items()}

# %%
model.components
# Out:
# [(('\\alpha', 'A_{solar}'), 0, ('D_f',), '2.0*(1/(3.14159265358979 - 3.14159265358979*\\alpha))**0.5*Abs(A_{solar})**0.5'),
#  (('\\alpha', 'D_f'), 1, ('d',), '\\alpha*D_f'),
#  (('h_f', 't_d', 'D_s', 'D_d', 't_s', 'D_f'), 2, ('Vd',), '0.785398163397448*D_d**2*t_d + 0.785398163397448*D_f**2*h_f + 0.785398163397448*D_s**2*t_s'),
#  (('\\rho_w', 'g', 'Vd'), 3, ('F_B',), '\\rho_w*g*Vd'),
#  (('F_B',), 4, ('F_W',), 'F_B'),
#  (('h_f', 'D_s', 't_s', 't_d', 'D_d', 'D_f'), 5, ('K_B',), '(D_d*t_d**2/2 + D_f*h_f*(h_f/2 + t_d + t_s) + D_s*t_s*(t_d + t_s/2))/(D_d*t_d + D_f*h_f + D_s*t_s)'),
#  (('t_f', 'D_s', 't_s', 't_d', 'D_d', 'D_f'), 6, ('K_G',), '(D_d*t_d**2/2 + D_f*t_f*(t_d + t_f/2 + t_s) + D_s*t_s*(t_d + t_s/2))/(D_d*t_d + D_f*t_f + D_s*t_s)'),
#  (('D_f',), 7, ('I',), '0.0490873852123405*D_f**4'),
#  (('Vd', 'I'), 8, ('B_M',), 'I/Vd'),
#  (('B_M', 'K_G', 'K_B'), 9, ('G_M',), 'B_M + K_B - K_G'),
#  (('\\rho_w', 'g', 'D_f'), 10, ('C_{33}',), '0.785398163397448*\\rho_w*g*D_f**2'),
#  (('\\rho_w', 'D_s', 'D_d', 'D_f'), 11, ('A_{33}',), '0.164933614313464*\\rho_w*(D_d**3 + D_f**3 + D_s**3)'),
#  (('C_{33}', 'm_{platform}', 'A_{33}'), 12, ('\\omega_0',), 'C_{33}/(2*(A_{33} + m_{platform}))'),
#  (('g', 'F_W'), 13, ('m_{platform}',), 'F_W/g'),
#  (('\\eta_{solar}', 'A_{solar}'), 14, ('m_{solar}',), '\\eta_{solar}*A_{solar}'),
#  (('m_{prop}', 'm_{platform}', 'm_{comms}', 'm_{batt}', 'm_{solar}'), 15, ('m_{struct}',), '-m_{comms} - m_{prop} - m_{batt} + m_{platform} - m_{solar}'),
#  (('m_{struct}', 't_f', 'D_s', 't_s', '\\rho_h', '\\rho', 'D_d', 'D_f'), 16, ('t_d',), '(-\\rho*D_f**2*t_f - \\rho*D_s**2*t_s + 1.27323954473516*m_{struct})/(\\rho_h*D_d**2)'),
#  (('h_f', 't_d', 'D_d', 'D_s', 't_s', 'D_f'), 17, ('S_w',), '1.5707963267949*D_d**2 + 3.14159265358979*D_d*t_d + 0.785398163397448*D_f**2 + 3.14159265358979*D_f*h_f - 1.5707963267949*D_s**2 + 3.14159265358979*D_s*t_s'),
#  (('v', '\\eta_m', '\\rho_w', 'S_w', 'C_d'), 18, ('P_{move}',), 'C_d*\\rho_w*S_w*v**3/(2*\\eta_m)'),
#  (('f', 'c'), 19, ('\\lambda',), 'c/f'),
#  (('\\theta_t', 'e_t'), 20, ('L_{pt}',), '-12*e_t**2/\\theta_t**2'),
#  (('\\lambda', '\\eta_{parab}', 'd'), 21, ('G_t',), '9.86960440108936*\\eta_{parab}*d**2/\\lambda**2'),
#  (('D_r', '\\eta_{parab}', '\\lambda'), 22, ('G_r',), '9.86960440108936*D_r**2*\\eta_{parab}/\\lambda**2'),
#  (('Re', 'h'), 23, ('S',), 'sqrt(h*(2*Re + h))'),
#  (('S', '\\lambda'), 24, ('L_s',), '0.00633257397764611*\\lambda**2/S**2'),
#  (('L_l', 'R', 'L_p', 'G_t', 'EN', 'G_r', 'k', 'L_s', 'L_a', 'T_s'), 25, ('P_{comms}',), 'T_s*k*EN*R/(L_a*L_l*L_p*G_r*G_t*L_s)'),
#  (('t_{move}', 'P_{move}'), 26, ('E_{move}',), 't_{move}*P_{move}'),
#  (('t_{mission}', 'P_{hotel}'), 27, ('E_{hotel}',), 'P_{hotel}*t_{mission}'),
#  (('t_{comms}', 'P_{comms}'), 28, ('E_{comms}',), 't_{comms}*P_{comms}'),
#  (('E_{AUV}', '\\gamma'), 29, ('E_{service}',), 'E_{AUV}*\\gamma'),
#  (('t_{service}', 'E_{service}'), 30, ('P_{service}',), 'E_{service}/t_{service}'),
#  (('E_{service}', 'E_{move}', 'E_{hotel}', 'E_{comms}'), 31, ('E_{required}',), 'E_{comms} + E_{hotel} + E_{move} + E_{service}'),
#  (('E_{required}',), 32, ('E_{recharge}',), 'E_{required}'),
#  (('t_{recharge}', 'E_{recharge}'), 33, ('P_{recharge}',), 'E_{recharge}/t_{recharge}'),
#  (('L_{solar}', 'd_{deg}', '\\phi_s', '\\eta_s', '\\theta', 'P_{recharge}', 'I_{deg}'), 34, ('A_{solar}',), 'P_{recharge}/(I_{deg}*\\eta_s*\\phi_s*(1 - d_{deg})**L_{solar}*cos(\\theta))'),
#  (('N', 'DOD', 'E_{required}', '\\eta_{battery}'), 35, ('C',), 'E_{required}/(DOD*N*\\eta_{battery})'),
#  (('m_{batt_zero}', '\\mu_{battery}', 'C'), 36, ('m_{batt}',), 'm_{batt_zero} + C/\\mu_{battery}')]

# %%
render_incidence(edges_nopar, tree, figname="pearl_default_hsm.png", save=False, rawvarname=True, 
                         dispendcomp=False, hideticks=True, patchwidth=4, figsize=((15,15)));
