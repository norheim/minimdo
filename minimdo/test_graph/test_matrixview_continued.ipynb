# %%
from graph.matrixview import render_incidence
from collections import OrderedDict

# %% [markdown]
# Next example

# %% [markdown]
# ![image.png](attachment:32bf0a1f-641f-4dae-865f-c8b1ac9f2b81.png)

# %%
edges = ({0: ('A',),
  1: ('m_t',),
  2: ('P_s', 'P_d'),
  3: ('m_t',),
  4: ('m_s', 'A', 'm_t')},
 {0: ('P_s',), 
  1: ('P_d',), 
  2: (None,), 
  3: ('m_s',), 
  4: (None,)},
 {})
tree = (
    OrderedDict([(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]), 
    {}, 
    {'A': 1, 'm_t': 1})

# %%
render_incidence(edges, tree, rawvarname=True,hideticks=True, figsize=(2,2), fontsize=12);
